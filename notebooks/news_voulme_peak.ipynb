# %% [markdown]
# ---
# title:Anomaly Detection of News Volume Data
# space: INTFEL
# parent: Yihan ZHONG
# comment: Exploring methods to identify and analyze significant peak in news volume to gain insights into the corresponding events.
# ---

# %% [markdown]
# ## Package and functions

# %%
import pandas as pd
from pathlib import Path
path = Path('/mnt/research-live/equity/reference/equity_data/sa_research/current/')
import pandas as pd 
import numpy as np 
import re

# %%
def ts_scale(v, halflife=252, min_periods=126, periods=None, use_std=True, ignore_na=False, nb_bins=1):
    """
    ts_scale:
        nb_bins (int): Number of bins, to scale the halflife to nb of days.
            Default is one for our daily program, but allows to accomodate for short term programs.
    """
    halflife *= nb_bins
    min_periods *= nb_bins
    if periods is not None: 
        periods *= nb_bins

    if periods is not None:
        v_ = v.pipe(nnan_shift, periods)
    else: 
        v_ = v
    if use_std: 
        std = v_.ewm(halflife=halflife, min_periods=min_periods, ignore_na=ignore_na).std()
    else: 
        std = v_.abs().ewm(halflife=halflife, min_periods=min_periods, ignore_na=ignore_na).mean()
    return v.div(std)

def ts_demean(v, halflife=252, ignore_na=False, min_periods=0, nb_bins=1):
    halflife *= nb_bins
    min_periods *= nb_bins
    return v.sub(v.ewm(halflife, ignore_na=ignore_na, min_periods=min_periods).mean())

# %%
def ts_zscore(v, halflife=252, ignore_na=False, min_periods=126, nb_bins=1, last_year_weight=False, last_year_news_weight=False):
    """
    Calculate the z-score of a time series with different weightage options.
    
    Inputs:
    - v: Time series data.
    - halflife: Halflife parameter for exponential weighting.
    - ignore_na: Flag to ignore NaN values 
    - min_periods: Minimum number of observations required for exponential weighting .
    - nb_bins: Number of bins to scale the halflife .
    - last_year_weight: Flag to apply weightage based on the number of days with news in the last year (default: False).
    - last_year_news_weight: Flag to apply weightage based on the average number of news in the last year (default: False).
    
    Outputs:
    - Z-scored time series.
    """
    if last_year_weight:
        last_year = v.index.year[-1]
        if last_year == 2008:
            n_days = (v[v.index.year == last_year] != 0).sum()
        else:
            n_days = (v[v.index.year == last_year - 1] != 0).sum()
        weight = np.sqrt(n_days)
        scaled = ts_scale(v, halflife=halflife, ignore_na=ignore_na, min_periods=min_periods, nb_bins=nb_bins)
        return scaled * weight
    elif last_year_news_weight:
        last_year = v.index.year[-1]
        if last_year == 2008:
            n_news = (v[v.index.year == last_year]).mean()
        else:
            n_news = (v[v.index.year == last_year - 1]).mean()
        weight = np.sqrt(n_news)
        scaled = ts_scale(v, halflife=halflife, ignore_na=ignore_na, min_periods=min_periods, nb_bins=nb_bins)
        return scaled * weight
    else:
        return ts_scale(ts_demean(v, halflife=halflife, ignore_na=ignore_na, min_periods=min_periods, nb_bins=nb_bins), halflife=halflife, ignore_na=ignore_na, min_periods=min_periods, nb_bins=nb_bins)

# %%
def plot_volume(eqt_code,news_volume_):
    news_volume_.query(f'eqt_code == {eqt_code}').set_index('event_date')['total_count'].sort_index().plot()
def plot_z_score(eqt_code,z_score_matrix):
    z_score_matrix[eqt_code].plot()

# %% [markdown]
# ## Data Loading

# %%
from pathlib import Path
path = Path('/mnt/research-live/equity/reference/equity_data/sa_research/current/')
ead_ = pd.read_parquet(path /'CFM_AMER/equity_data/eqt_earning_announcement_dates.parquet') # date for earnings
news_volume__ =pd.read_parquet(path /'CFM_AMER/equity_data/eqt_bb_news_volumes.parquet') # volume for each date
eqt=pd.read_parquet('/mnt/research-live/equity/reference/equity_data/sa_research/current/CFM_AMER/equity_data/eqt_referential.parquet') #name of company

# %% [markdown]
# Filtering the earning days from the dataset

# %%
news_volume__['id']=news_volume__.index
filtered_df = news_volume__.merge(ead_, left_on=['eqt_code', 'event_date'], right_on=['eqt_code', 'earning_date'], how='inner')
news_volume_ = news_volume__[~news_volume__['id'].isin(filtered_df['id'])][['event_date', 'eqt_code', 'total_count']]

# %%
'''
creating a new DataFrame `news_volume_pivot` 
with `total_count` as values,
`event_date` as the index, 
`eqt_code` as columns, 
and filling missing values with `np.nan`.
'''
news_volume_pivot = news_volume_.pivot_table(values='total_count', index='event_date', columns='eqt_code', fill_value=np.nan)

# %% [markdown]
# ## Vanilla Method: No Weighting or Data Filling

# %%
z_score_matrix = news_volume_pivot.apply(lambda x: ts_zscore(x, halflife=252, ignore_na=True, min_periods=126, nb_bins=1), axis=0)

# %%
news_volume_.query(f'eqt_code == "SGMO1_UQ"').set_index('event_date')['total_count'].sort_index().plot()
# Out:
# <AxesSubplot:xlabel='event_date'>

# %%
z_score_matrix["AAPL_UQ"].plot()
# Out:
# <AxesSubplot:xlabel='event_date'>

# %% [markdown]
# ### Results for the top 50 z-score

# %%
top_30=z_score_matrix.stack().sort_values(ascending=False).head(30).reset_index()
top_30
# Out:
#    event_date  eqt_code          0
# 0  2023-03-10   SIVB_UQ  18.425088
# 1  2018-01-30    TOC_CN  17.488349
# 2  2018-01-30   TRI1_UN  17.463764
# 3  2020-09-29    NTT_UN  17.171782
# 4  2014-09-26     SV_UN  17.005758
# 5  2016-07-18   ARMH_UW  16.978181
# 6  2014-08-25    THI_UN  16.717772
# 7  2014-08-25    THI_CT  16.687271
# 8  2016-02-09    FTS_CT  16.667919
# 9  2021-01-13  ATD_B_CT  16.629087
# 10 2013-03-14    AEE_UN  16.581715
# 11 2023-03-13   SBNY_UQ  16.513459
# 12 2015-08-10    PCP_UN  16.493183
# 13 2021-01-28    GME_UN  16.464202
# 14 2015-02-19    BLL_UN  16.416014
# 15 2016-08-22  ATD_B_CT  16.368554
# 16 2014-09-22   SIAL_UQ  16.342407
# 17 2020-11-30    MHP_UN  16.282905
# 18 2019-12-16  CGX_U_CT  16.126288
# 19 2012-07-23    NXY_CN  16.090855
# 20 2017-07-03   TROV_US  16.061836
# 21 2013-12-09    SYY_UN  16.054587
# 22 2017-05-02    IIC_CT  16.009054
# 23 2013-07-15     SC_CN  15.979630
# 24 2013-02-14    HNZ_UN  15.940132
# 25 2016-04-04    ALK_UN  15.938580
# 26 2023-03-10   FRC2_UN  15.932233
# 27 2014-07-23   BA_U_CT  15.929522
# 28 2021-01-27    GME_UN  15.925665
# 29 2020-11-30   MRKT_US  15.883660

# %%
eqt.loc['PH_UN', 'cmp_name']
# Out:
# 'Parker-Hannifin Corp'

# %%
merged_df = top_30.merge(news_volume__[["event_date", "eqt_code", "total_count"]], on=["event_date", "eqt_code"], how="left")
merged_df['company_name'] = merged_df['eqt_code'].map(eqt['cmp_name'])
merged_df.sort_values(by='total_count', ascending=False)
# Out:
#    event_date  eqt_code          0  total_count  \
# 0  2023-03-10   SIVB_UQ  18.425088          580
# 13 2021-01-28    GME_UN  16.464202          406
# 5  2016-07-18   ARMH_UW  16.978181          254
# 19 2012-07-23    NXY_CN  16.090855          215
# 24 2013-02-14    HNZ_UN  15.940132          207
# 28 2021-01-27    GME_UN  15.925665          200
# 11 2023-03-13   SBNY_UQ  16.513459          164
# 3  2020-09-29    NTT_UN  17.171782          163
# 4  2014-09-26     SV_UN  17.005758          161
# 12 2015-08-10    PCP_UN  16.493183          159
# 16 2014-09-22   SIAL_UQ  16.342407          134
# 25 2016-04-04    ALK_UN  15.938580          126
# 2  2018-01-30   TRI1_UN  17.463764          113
# 1  2018-01-30    TOC_CN  17.488349          113
# 6  2014-08-25    THI_UN  16.717772          110
# 7  2014-08-25    THI_CT  16.687271          110
# 17 2020-11-30    MHP_UN  16.282905          107
# 14 2015-02-19    BLL_UN  16.416014          104
# 20 2017-07-03   TROV_US  16.061836          102
# 10 2013-03-14    AEE_UN  16.581715          101
# 29 2020-11-30   MRKT_US  15.883660          100
# 9  2021-01-13  ATD_B_CT  16.629087           91
# 21 2013-12-09    SYY_UN  16.054587           89
# 8  2016-02-09    FTS_CT  16.667919           78
# 26 2023-03-10   FRC2_UN  15.932233           75
# 15 2016-08-22  ATD_B_CT  16.368554           73
# 23 2013-07-15     SC_CN  15.979630           64
# 27 2014-07-23   BA_U_CT  15.929522           47
# 22 2017-05-02    IIC_CT  16.009054           33
# 18 2019-12-16  CGX_U_CT  16.126288           26
#
#                          company_name
# 0                 SVB Financial Group
# 13                      GameStop Corp
# 5                    ARM Holdings PLC
# 19                          Nexen Inc
# 24               Kraft Heinz Foods Co
# 28                      GameStop Corp
# 11         Signature Bank/New York NY
# 3   Nippon Telegraph & Telephone Corp
# 4             Janus Capital Group Inc
# 12           Precision Castparts Corp
# 16                 Sigma-Aldrich Corp
# 25               Alaska Air Group Inc
# 2                Thomson Reuters Corp
# 1                Thomson Reuters Corp
# 6                     Tim Hortons Inc
# 7                     Tim Hortons Inc
# 17                     S&P Global Inc
# 14                          Ball Corp
# 20               Cardiff Oncology Inc
# 10                        Ameren Corp
# 29                     IHS Markit Ltd
# 9        Alimentation Couche-Tard Inc
# 21                         Sysco Corp
# 8                   Fortis Inc/Canada
# 26             First Republic Bank/CA
# 15       Alimentation Couche-Tard Inc
# 23            Shoppers Drug Mart Corp
# 27                    Bell Aliant Inc
# 22              Intact Financial Corp
# 18                       Cineplex Inc

# %% [markdown]
# ### Problems encountered

# %% [markdown]
# This method may introduce bias, as the NaN values can impact the z-score, potentially underestimating the significance of sudden news appearances.

# %% [markdown]
# ## Method 1: fill the news volume with 0 from the first day that one company has news

# %%
'''
Filling the news_volume_pivot table with 0
when it first encounter a non null value
'''
for column in news_volume_pivot:
    mask = news_volume_pivot[column].notnull()
    if mask.any():
        first_valid_index = mask.idxmax()
        news_volume_pivot.loc[first_valid_index:, column].fillna(0, inplace=True)

# %%
z_score_matrix = news_volume_pivot.apply(lambda x: ts_zscore(x, halflife=252, ignore_na=True, min_periods=126, nb_bins=1), axis=0)

# %% [markdown]
# ### Results for the top 50 z-score

# %%
top_30=z_score_matrix.stack().sort_values(ascending=False).head(30).reset_index()

# %%
merged_df = top_30.merge(news_volume__[["event_date", "eqt_code", "total_count"]], on=["event_date", "eqt_code"], how="left")
merged_df['company_name'] = merged_df['eqt_code'].map(eqt['cmp_name'])
merged_df.sort_values(by='total_count', ascending=False)
# Out:
#    event_date  eqt_code          0  total_count  \
# 10 2014-06-02   AEGR_US  18.726956         1163
# 2  2014-06-02   BEBE_UQ  19.034207         1156
# 16 2014-06-02   FLDM_US  18.596970         1043
# 17 2014-06-02   PAMT_US  18.584369         1037
# 12 2014-06-02   ZGNX_US  18.667584          832
# 5  2014-06-02   SGYP_UV  18.972696          727
# 1  2014-06-02  PDII1_UQ  19.037595          725
# 3  2014-06-02  SGMO1_UQ  19.019451          723
# 4  2014-06-02   RBCN_US  19.015763          721
# 11 2023-03-10   SIVB_UQ  18.713169          580
# 9  2023-03-13   SBNY_UQ  18.727012          164
# 7  2014-09-26     SV_UN  18.774377          161
# 18 2014-09-22   SIAL_UQ  18.559731          134
# 24 2013-12-16    AER_UN  18.395762          128
# 23 2023-03-27  FCNCA_UQ  18.451206           94
# 13 2017-07-03   WFSL_UQ  18.666126           66
# 8  2014-04-15   ZBRA_UQ  18.727672           62
# 25 2017-07-03   SBNY_UQ  18.390345           58
# 27 2017-07-03   PPBI_US  18.375259           55
# 22 2017-07-03   TZOO_UQ  18.463354           33
# 15 2017-07-03   WABC_UQ  18.599840           33
# 26 2017-07-03   BVSN_US  18.377873           30
# 19 2017-07-03   CFFN_UQ  18.542671           29
# 21 2017-07-03   CLFD_US  18.516784           29
# 29 2020-01-30    CUK_UN  18.363244           21
# 0  2018-08-10   MESA_UQ  19.066185            9
# 28 2019-04-16   EVSI_UV  18.374939            3
# 14 2015-09-18   TSCC_UQ  18.647364            2
# 6  2015-11-19    CUK_UN  18.805566            2
# 20 2012-04-18   ALSC_UQ  18.520769            1
#
#                         company_name
# 10      Aegerion Pharmaceuticals Inc
# 2                    Bebe Stores Inc
# 16             Standard BioTools Inc
# 17                 Turtle Beach Corp
# 12                       Zogenix Inc
# 5        Synergy Pharmaceuticals Inc
# 1          Interpace Biosciences Inc
# 3           Sangamo Therapeutics Inc
# 4             Rubicon Technology Inc
# 11               SVB Financial Group
# 9         Signature Bank/New York NY
# 7            Janus Capital Group Inc
# 18                Sigma-Aldrich Corp
# 24                AerCap Holdings NV
# 23  First Citizens BancShares Inc/NC
# 13            Washington Federal Inc
# 8            Zebra Technologies Corp
# 25        Signature Bank/New York NY
# 27       Pacific Premier Bancorp Inc
# 22                         Travelzoo
# 15               Westamerica BanCorp
# 26                   BroadVision Inc
# 19     Capitol Federal Financial Inc
# 21                    Clearfield Inc
# 29                      Carnival PLC
# 0                 Mesa Air Group Inc
# 28                       Beam Global
# 14           Technology Solutions Co
# 6                       Carnival PLC
# 20             Alimco Financial Corp

# %% [markdown]
# ### Problems encountered

# %% [markdown]
# From the given example, it is evident that when an enterprise does not have any news updates between the dates 2012-01-17 and 2015-11-19, the calculated z-score for the date 2015-11-19 may be biased or misleading.

# %%
news_volume__[(news_volume__.eqt_code=='CUK_UN')]
# Out:
#         event_date utilisation_date_local eqt_daprice_local cfm_date_type  \
# 813275  2012-01-17             2012-01-18        2012-01-17          HIST
# 2293680 2015-11-19             2015-11-20        2015-11-19          HIST
# 2298406 2015-11-24             2015-11-25        2015-11-24          HIST
# 2339529 2016-01-06             2016-01-07        2016-01-06          HIST
# 2349578 2016-01-14             2016-01-15        2016-01-14          HIST
# ...            ...                    ...               ...           ...
# 4163253 2023-03-16             2023-03-17        2023-03-16           PIT
# 4167189 2023-03-27             2023-03-28        2023-03-27           PIT
# 4173208 2023-04-11             2023-04-12        2023-04-11           PIT
# 4174844 2023-04-14             2023-04-17        2023-04-14           PIT
# 4176183 2023-04-18             2023-04-19        2023-04-18           PIT
#
#             cfm_adjust_date     cfm_insert_date utilisation_date    daclose  \
# 813275  2012-01-18 03:30:00 2012-01-18 03:30:00       2012-01-18 2012-01-17
# 2293680 2015-11-20 03:30:00 2015-11-20 03:30:00       2015-11-20 2015-11-19
# 2298406 2015-11-25 03:30:00 2015-11-25 03:30:00       2015-11-25 2015-11-24
# 2339529 2016-01-07 03:30:00 2016-01-07 03:30:00       2016-01-07 2016-01-06
# 2349578 2016-01-15 03:30:00 2016-01-15 03:30:00       2016-01-15 2016-01-14
# ...                     ...                 ...              ...        ...
# 4163253 2023-03-17 03:30:00 2023-03-17 03:30:00       2023-03-17 2023-03-16
# 4167189 2023-03-28 03:30:00 2023-03-28 03:30:00       2023-03-28 2023-03-27
# 4173208 2023-04-12 03:30:00 2023-04-12 03:30:00       2023-04-12 2023-04-11
# 4174844 2023-04-15 03:30:00 2023-04-15 03:30:00       2023-04-17 2023-04-14
# 4176183 2023-04-19 03:30:00 2023-04-19 03:30:00       2023-04-19 2023-04-18
#
#         eqt_code  total_count  ...  count_pos_mret  count_neg_mret  \
# 813275    CUK_UN            1  ...               0               1
# 2293680   CUK_UN            2  ...               0               0
# 2298406   CUK_UN            1  ...               0               1
# 2339529   CUK_UN            2  ...               1               0
# 2349578   CUK_UN            3  ...               0               1
# ...          ...          ...  ...             ...             ...
# 4163253   CUK_UN            1  ...               0               1
# 4167189   CUK_UN           10  ...               0              10
# 4173208   CUK_UN            1  ...               0               0
# 4174844   CUK_UN            1  ...               0               0
# 4176183   CUK_UN            2  ...               0               0
#
#          count_pos_roberta_headline  count_neg_roberta_headline  \
# 813275                            0                           1
# 2293680                           0                           0
# 2298406                           0                           1
# 2339529                           0                           0
# 2349578                           1                           0
# ...                             ...                         ...
# 4163253                           1                           0
# 4167189                           5                           4
# 4173208                           0                           0
# 4174844                           0                           0
# 4176183                           0                           0
#
#          total_readership  readership_pos_sent  readership_neg_sent  \
# 813275                  0                    0                    0
# 2293680               125                    0                    0
# 2298406                 0                    0                    0
# 2339529                25                    0                    0
# 2349578                75                    0                    0
# ...                   ...                  ...                  ...
# 4163253                25                    0                    0
# 4167189                50                    0                   25
# 4173208                 0                    0                    0
# 4174844                 0                    0                    0
# 4176183                 0                    0                    0
#
#          readership_pos_mret  readership_neg_mret       id
# 813275                     0                    0   813275
# 2293680                  125                    0  2293680
# 2298406                    0                    0  2298406
# 2339529                   25                    0  2339529
# 2349578                    0                   75  2349578
# ...                      ...                  ...      ...
# 4163253                    0                   25  4163253
# 4167189                    0                   50  4167189
# 4173208                    0                    0  4173208
# 4174844                    0                    0  4174844
# 4176183                    0                    0  4176183
#
# [329 rows x 22 columns]

# %% [markdown]
# ## Method2: Weighting the z-score

# %% [markdown]
# ### A.  Based on the number of days within the last year that a company has news updates.

# %%
z_score_matrix = news_volume_pivot.apply(lambda x: ts_zscore(x, halflife=252, ignore_na=True, min_periods=126, nb_bins=1, last_year_weight=True), axis=0)

# %%
top_30=z_score_matrix.stack().sort_values(ascending=False).head(30).reset_index()

# %% [markdown]
# **Example of the news:**
#
# Twitter:
#
# - On April 13, 2022, Elon Musk announced the acquisition of Twitter.
# - On September 5, 2018, Twitter faced controversy over supposed account shadow banning. The company claimed it was a bug that resulted in the unfair filtering of 600,000 accounts.

# %%
top_100[top_100['eqt_code']=='TWTR_US']
# Out:
#    event_date eqt_code           0
# 28 2022-04-14  TWTR_US  237.201116
# 83 2018-09-05  TWTR_US  212.235767

# %%
merged_df = top_30.merge(news_volume__[["event_date", "eqt_code", "total_count"]], on=["event_date", "eqt_code"], how="left")
merged_df['company_name'] = merged_df['eqt_code'].map(eqt['cmp_name'])
merged_df.sort_values(by='total_count', ascending=False)
# Out:
#    event_date  eqt_code           0  total_count  \
# 5  2023-03-10   SIVB_UQ  257.898156          580
# 14 2023-03-20    UBS_UN  246.466352          455
# 2  2019-03-11     BA_UN  273.526984          433
# 22 2023-03-15    CS2_UN  240.144727          378
# 4  2011-08-08  BVMF3_BS  260.553537          368
# 1  2014-04-28    AZN_UN  277.978669          353
# 13 2021-04-13    JNJ_UN  247.227687          322
# 28 2022-04-14   TWTR_US  237.201116          310
# 3  2023-03-19    UBS_UN  261.548093          294
# 7  2014-04-28    PFE_UN  256.253570          267
# 26 2014-04-22    GSK_UN  237.610340          227
# 20 2011-03-21    SBC_UN  240.508757          218
# 12 2021-01-28    AMC_US  249.411833          216
# 11 2009-12-03  CMCSA_UQ  251.725535          199
# 9  2009-12-03  CMCSK_UQ  253.398149          199
# 25 2012-01-16    CCL_UN  238.582758          192
# 16 2021-05-17    SBC_UN  245.509969          164
# 21 2021-05-17  DISCA_UQ  240.423966          161
# 15 2013-02-05    MHP_UN  246.051549          148
# 8  2021-03-29  VIA_B_UN  256.018619          142
# 27 2012-11-12    LUK_UN  237.489328          132
# 19 2022-01-18   ATVI_UQ  240.762759          119
# 0  2020-11-30    MHP_UN  298.755840          107
# 18 2019-04-24    OXY_UN  242.889688           95
# 10 2021-03-29  DISCA_UQ  252.245553           92
# 6  2019-02-07    BBT_UN  257.430066           87
# 24 2020-01-30    CCL_UN  238.688844           78
# 17 2016-03-04    AMC_US  244.423408           77
# 29 2022-01-17     UL_UN  237.138192           69
# 23 2017-07-03   MSTR_UQ  239.189005           35
#
#                       company_name
# 5              SVB Financial Group
# 14                    UBS Group AG
# 2                    Boeing Co/The
# 22          Credit Suisse Group AG
# 4      B3 SA - Brasil Bolsa Balcao
# 1                  AstraZeneca PLC
# 13               Johnson & Johnson
# 28                     Twitter Inc
# 3                     UBS Group AG
# 7                       Pfizer Inc
# 26                         GSK PLC
# 20                        AT&T Inc
# 12  AMC Entertainment Holdings Inc
# 11                    Comcast Corp
# 9                     Comcast Corp
# 25                   Carnival Corp
# 16                        AT&T Inc
# 21       Warner Bros Discovery Inc
# 15                  S&P Global Inc
# 8                 Paramount Global
# 27   Jefferies Financial Group Inc
# 19         Activision Blizzard Inc
# 0                   S&P Global Inc
# 18       Occidental Petroleum Corp
# 10       Warner Bros Discovery Inc
# 6            Truist Financial Corp
# 24                   Carnival Corp
# 17  AMC Entertainment Holdings Inc
# 29                    Unilever PLC
# 23               MicroStrategy Inc

# %% [markdown]
# ### B.  Based on the number of news within the last year that a company has updated.

# %%
z_score_matrix = news_volume_pivot.apply(lambda x: ts_zscore(x, halflife=252, ignore_na=True, min_periods=126, nb_bins=1, last_year_weight=False, last_year_news_weight=True), axis=0)

# %%
top_30=z_score_matrix.stack().sort_values(ascending=False).head(30).reset_index()
top_30
# Out:
#    event_date  eqt_code          0
# 0  2012-09-25   TSLA_UW  66.099328
# 1  2022-04-14   TWTR_US  61.320663
# 2  2011-08-25   AAPL_UQ  59.046817
# 3  2014-09-09   AAPL_UQ  55.756211
# 4  2018-09-05   TWTR_US  54.866681
# 5  2011-10-06   AAPL_UQ  54.514649
# 6  2013-09-03   MSFT_UQ  53.047718
# 7  2019-01-03   AAPL_UQ  51.257647
# 8  2011-03-03     RY_CN  51.191281
# 9  2015-04-08  RDS_A_UN  50.493716
# 10 2019-03-11     BA_UN  50.282123
# 11 2012-01-17   TSLA_UW  49.362063
# 12 2018-03-20     FB_US  49.042725
# 13 2014-07-31   TSLA_UW  48.448336
# 14 2012-05-09   TSLA_UW  47.898057
# 15 2023-03-15    CS2_UN  47.737051
# 16 2016-06-13   MSFT_UQ  47.664474
# 17 2017-06-16   AMZN_UQ  47.252801
# 18 2013-08-07   TSLA_UW  47.124099
# 19 2020-05-28   TWTR_US  46.494329
# 20 2014-11-05   TSLA_UW  46.451375
# 21 2010-01-27   AAPL_UQ  46.111803
# 22 2010-04-19     GS_UN  45.671074
# 23 2016-02-10   TSLA_UW  45.474492
# 24 2015-08-05   TSLA_UW  45.157762
# 25 2011-02-15   TSLA_UW  44.656818
# 26 2015-05-01   TSLA_UW  44.527255
# 27 2014-04-28    PFE_UN  44.338091
# 28 2023-05-01    CMB_UN  44.028046
# 29 2016-09-07   AAPL_UQ  43.532595

# %%
merged_df = top_30.merge(news_volume__[["event_date", "eqt_code", "total_count"]], on=["event_date", "eqt_code"], how="left")
merged_df['company_name'] = merged_df['eqt_code'].map(eqt['cmp_name'])
merged_df.sort_values(by='total_count', ascending=False)
# Out:
#    event_date  eqt_code          0  total_count                 company_name
# 22 2010-04-19     GS_UN  45.671074          557  Goldman Sachs Group Inc/The
# 3  2014-09-09   AAPL_UQ  55.756211          508                    Apple Inc
# 5  2011-10-06   AAPL_UQ  54.514649          490                    Apple Inc
# 2  2011-08-25   AAPL_UQ  59.046817          439                    Apple Inc
# 10 2019-03-11     BA_UN  50.282123          433                Boeing Co/The
# 6  2013-09-03   MSFT_UQ  53.047718          431               Microsoft Corp
# 15 2023-03-15    CS2_UN  47.737051          378       Credit Suisse Group AG
# 29 2016-09-07   AAPL_UQ  43.532595          375                    Apple Inc
# 7  2019-01-03   AAPL_UQ  51.257647          352                    Apple Inc
# 1  2022-04-14   TWTR_US  61.320663          310                  Twitter Inc
# 16 2016-06-13   MSFT_UQ  47.664474          295               Microsoft Corp
# 9  2015-04-08  RDS_A_UN  50.493716          279                    Shell PLC
# 12 2018-03-20     FB_US  49.042725          267           Meta Platforms Inc
# 27 2014-04-28    PFE_UN  44.338091          267                   Pfizer Inc
# 28 2023-05-01    CMB_UN  44.028046          237          JPMorgan Chase & Co
# 17 2017-06-16   AMZN_UQ  47.252801          206               Amazon.com Inc
# 21 2010-01-27   AAPL_UQ  46.111803          188                    Apple Inc
# 4  2018-09-05   TWTR_US  54.866681          171                  Twitter Inc
# 24 2015-08-05   TSLA_UW  45.157762          131                    Tesla Inc
# 20 2014-11-05   TSLA_UW  46.451375          125                    Tesla Inc
# 23 2016-02-10   TSLA_UW  45.474492          125                    Tesla Inc
# 13 2014-07-31   TSLA_UW  48.448336          123                    Tesla Inc
# 26 2015-05-01   TSLA_UW  44.527255          120                    Tesla Inc
# 19 2020-05-28   TWTR_US  46.494329          106                  Twitter Inc
# 8  2011-03-03     RY_CN  51.191281          101         Royal Bank of Canada
# 0  2012-09-25   TSLA_UW  66.099328           99                    Tesla Inc
# 18 2013-08-07   TSLA_UW  47.124099           90                    Tesla Inc
# 14 2012-05-09   TSLA_UW  47.898057           56                    Tesla Inc
# 11 2012-01-17   TSLA_UW  49.362063           50                    Tesla Inc
# 25 2011-02-15   TSLA_UW  44.656818           45                    Tesla Inc

# %% [markdown]
# ## Method3: Filtering certain stocks based on condition

# %%
print(f'number of all eqt_code: {len(news_volume_pivot.columns.to_list())}')
# Out:
# number of all eqt_code: 4025

# %%
unique_years = news_volume_pivot.index.year.unique()  # Get unique year indices
columns_to_drop = []

for column in news_volume_pivot.columns:
    for year in unique_years:
        values = news_volume_pivot[column][news_volume_pivot.index.year == year]
        if (values == 0).all():
            columns_to_drop.append(column)
            break
        else:
            continue

# %%
print(f'number of dropped eqt_code: {len(columns_to_drop)}')
# Out:
# number of dropped eqt_code: 1375

# %%
news_volume_pivot_dropped = news_volume_pivot.drop(columns_to_drop, axis=1)

# %%
z_score_matrix = news_volume_pivot_dropped.apply(lambda x: ts_zscore(x, halflife=252, ignore_na=True, min_periods=126, nb_bins=1), axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/tmp/tmp/ipykernel_397145/2812374206.py in <module>
# ----> 1 z_score_matrix = news_volume_pivot_dropped.apply(lambda x: ts_zscore(x, halflife=252, ignore_na=True, min_periods=126, nb_bins=1), axis=0)
#
# NameError: name 'news_volume_pivot_dropped' is not defined

# %%
top_30=z_score_matrix.stack().sort_values(ascending=False).head(100).reset_index()
top_30

# %%
merged_df = top_30.merge(news_volume__[["event_date", "eqt_code", "total_count"]], on=["event_date", "eqt_code"], how="left")
merged_df['company_name'] = merged_df['eqt_code'].map(eqt['cmp_name'])
merged_df.sort_values(by='total_count', ascending=False)

# %% [markdown]
# ## Comments
