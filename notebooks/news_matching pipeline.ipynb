# %% [markdown]
# ## Functions and libraries

# %%
# en python:
import os
os.environ["https_proxy"] = "http://proxy.fr.cfm.fr:6060"
import sys
# adding src to the system path
sys.path.insert(0, '/home/yzhong/notebooks/getting_started')
import yaml
from src.extract_chinese_data import get_bloomberg_chinese_news, get_bloomberg_english_news
from datasets import Dataset
import numpy as np
import pandas as pd
import regex as re
import torch
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch.nn.functional as F
import seaborn as sns
import matplotlib.pyplot as plt
import faiss
from laserembeddings import Laser
# Out:
# Picked up JAVA_TOOL_OPTIONS: -Djava.io.tmpdir=/opt/tmp/tmp
# Picked up JAVA_TOOL_OPTIONS: -Djava.io.tmpdir=/opt/tmp/tmp
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/27 07:58:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/04/27 07:58:41 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# /home/yzhong/conda/envs/yihan_gpu/lib/python3.8/site-packages/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# /home/yzhong/conda/envs/yihan_gpu/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
DATA_PATH = "/mnt/research-live/user/yzhong/"

# %%
#remove space
def remove_space(text):
    text=text.replace(' ','')
    return text
#Full-width to half-width
def full_to_half(sentence):      
    change_sentence=""
    for word in sentence:
        inside_code=ord(word)
        if inside_code==12288:    #Direct conversion of full-width spaces
            inside_code=32
        elif inside_code>=65281 and inside_code<=65374:  #Full-width characters (except spaces) are converted according to the relationship
            inside_code-=65248
        change_sentence+=chr(inside_code)
    return change_sentence
# remove unnecessary symbols as well as things in paratheses     
def remove_special_chars(text):
    special_chars = r'[&*+\-\/<=>?@\^_|~]'
    # replace special characters with an empty string
    cleaned_text = re.sub(special_chars, '', text)
    pattern = r'\(.*?\)' # remove things in paratheses
    cleaned_text = re.sub(pattern, '', cleaned_text)
    return cleaned_text    
def add_chinese_period (string):
    """
    For stablized the translation
    """
    string=string+'。'
    return string
# Tokenize a sentence
def clean_str_english(string, tolower=True):
    """
    Tokenization/string cleaning.
    Original taken from https://github.com/yoonkim/CNN_sentence/blob/master/process_data.py
    """
    #string = re.sub(r"[^A-Za-z0-9(),!?\'\`]", " ", string)
    string = re.sub(r"\'s", " \'s", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"n\'t", " n\'t", string)
    string = re.sub(r"\'re", " \'re", string)
    string = re.sub(r"\'d", " \'d", string)
     # remove things in parathese
    string = re.sub(r'\(.*?\)', " \'d", string)
    string = re.sub(r'[&*+\-\/<=>?@\^_|~]', '', string)
    
    string = re.sub(r"\'ll", " \'ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)
    if tolower:
        string = string.lower()
    return string.strip()

# %%
def cosinus_similarity (emb1, emb2):
# cosine similarity = normalize the vectors & multiply
    C = F.normalize(torch.tensor(emb1)) @ F.normalize(torch.tensor(emb2)).t()
    return C.numpy()

# %%
def cosine_similarity(a, b=None): 
    """ 
    cosine_similarity: Compute cosine similarity between two arrays. 
    If second array is None, computes similarity with self. 
    Args: a (np.array): dimension (n_a, p) b (np.array): dimension (n_b, p)
    """ 
    a /= np.sqrt(np.diag(a @ a.T))[:, None]
    if b is None: 
        b = a 
    else: 
        b /= np.sqrt(np.diag(b @ b.T))[:, None] 
    return a @ b.T

# %%
import json
# read the config file into a dictionary
with open("/home/yzhong/notebooks/getting_started/config_transformer.json", "r") as f:
    config_ = json.load(f)

print(config_)
# Out:
# {'TRANSLATION_MODEL': 'Helsinki-NLP/opus-mt-zh-en', 'SENTENCE_TRANSFORMER': 'all-MiniLM-L6-v2', 'TRANSLATION_MODEL_ADVANCE': 'alirezamsh/small100', 'model_dir': '/opt/tmp/yzhong/models/'}

# %% [markdown]
# ## Prerequests: Read English and Chinese news from database

# %% [markdown]
# This notebooks requires a folder structure as this:
# - English_news_data/
#   - 2011/
#     - 01/
#       - bloomberg_news_english_2011_01_01.parquet
#       - bloomberg_news_english_2011_01_02.parquet
#       - ...
#     - 02/
#       - bloomberg_news_english_2011_02_01.parquet
#       - bloomberg_news_english_2011_02_02.parquet
#       - ...
#     - ...
#       - ...
#   - 2022/
#     - 01/
#       - bloomberg_news_english_2022_01_01.parquet
#       - bloomberg_news_english_2022_01_02.parquet
#       - ...
#     - 02/
#       - bloomberg_news_english_2022_02_01.parquet
#       - bloomberg_news_english_2022_02_02.parquet
#       - ...

# %% [markdown]
# Code for writing all the bloomberg English news into folder:

# %%
# Create the top-level directory for the English news data
if not os.path.exists("/mnt/live/user/yzhong/English_news_data"):
    os.mkdir("/mnt/live/user/yzhong/English_news_data")

for year in range(2011, 2023):
    year_str = str(year)

    # Create the year directory
    year_dir = os.path.join("/mnt/live/user/yzhong/English_news_data", year_str)
    if not os.path.exists(year_dir):
        os.mkdir(year_dir)

    for month in range(1, 13):
        month_str = f"{month:02d}"

        # Create the month directory
        month_dir = os.path.join(year_dir, month_str)
        if not os.path.exists(month_dir):
            os.mkdir(month_dir)

        # Determine the number of days in the month
        if month in [1, 3, 5, 7, 8, 10, 12]:
            num_days = 31
        elif month == 2:
            if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
                num_days = 29
            else:
                num_days = 28
        else:
            num_days = 30

        for day in range(1, num_days+1):
            day_str = f"{day:02d}"

            # Construct the date string in the required format
            date_str = f"{year_str}/{month_str}/{day_str}"

            # Load the data for the current date
            df_b = get_bloomberg_english_news(date=date_str)

            # Save the data to a parquet file in the appropriate directory
            filename = f'bloomberg_news_english_{year_str}_{month_str}_{day_str}.parquet'
            filepath = os.path.join(month_dir, filename)
            df_b.to_parquet(filepath)

# %% [markdown]
# For the Chinese news, it was possible to write them all at once, so an extra seperation job was done.

# %%
# get the Chinese dataframe with trickers. 
#set the language to Chinese_simplified 
df_b = get_bloomberg_chinese_news(date="*/*/*")
df_b.to_parquet('/mnt/research-live/user/yzhong/bloomberg_news_chinese_trickers.parquet')

# %% [markdown]
# ## Chinese news data

# %% [markdown]
# ### Translation

# %% [markdown]
# Model:

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu" #cuda:0 indique que tu veux être sur le 1er GPU, cuda:1 le 2e
MODEL_ID = config_['TRANSLATION_MODEL']
tokenizer = AutoTokenizer.from_pretrained( MODEL_ID, use_fast=True, cache_dir=config_['model_dir'] )
model = AutoModelForSeq2SeqLM.from_pretrained( MODEL_ID, cache_dir=config_['model_dir'] ).to(device)

# %% [markdown]
# Prepare the dataset

# %%
df = pd.read_parquet("/mnt/research-live/user/yzhong/bloomberg_news_chinese.parquet")
df_c=df[df.language=='CHINESE_SIMP'] #prepare the dataframe for Chinese
df_c['headline_org']=df_c.loc[:,"headline"]
df_c.dropna(inplace=True)
df_c.reset_index(drop=True, inplace=True)
df_c=df_c.reset_index().rename(columns={'index': 'id'})
df_c=Process_clean(df_c, lg='zh')

# %% [markdown]
# Run the model

# %%
batch_size : int = 32
#Prepare dataset
ds = Dataset.from_dict(df_c)
ds = ds.map(lambda x: compute_length(x, text='headline'), batched=True).sort('length', reverse=True)
ds = ds.map(lambda x: translate(x, tokenizer, model, text='headline'), batched=True, batch_size=batch_size).sort('id')

# %% [markdown]
# Stock the dataset with translation

# %%
ds.set_format("pandas")
df_c_t = ds[:]
df_c_t.to_parquet('/mnt/live/user/yzhong/bloomberg_news_chinese_translation.parquet')

# %% [markdown]
# ### Embeddings

# %% [markdown]
# Prepare the dataset

# %%
df_c=pd.read_parquet('/mnt/research-live/user/yzhong/bloomberg_news_chinese_trickers_translation.parquet')
df_c.dropna(subset=['headline'])
df_c.reset_index(drop=True, inplace=True)
df_c=df_c.reset_index().rename(columns={'index': 'id'})
df_c.loc[:,"translation"] = df_c.translation.apply(lambda x: clean_str(x))
ds_t = Dataset.from_dict(df_c)
cols_to_remove = ds_t.column_names
cols_to_remove.remove("translation")
cols_to_remove.remove("id")
ds_t1=ds_t.remove_columns(cols_to_remove)

# %% [markdown]
# Prepare the model

# %%
MODEL_ID = config_['SENTENCE_TRANSFORMER']
model = SentenceTransformer(MODEL_ID,device='cuda',cache_folder=config_['model_dir'] )
# Use the map method to apply the mapping function to the dataset in batches
batch_size =256*4

# %% [markdown]
# Obtain the embeddings

# %%
ds_t1 = ds_t1.map(lambda x: compute_length(x, text='translation'), batched=True).sort('length', reverse=True)
ds_t1 = ds_t1.map(lambda x: sentence_embeddings(x ,model, text='translation'), batched=True, batch_size=batch_size).sort('id')

# %%
translated_input_ids=ds_t1['embeddings']
df_c.to_parquet('/mnt/research-live/user/yzhong/bloomberg_news_chinese_trickers_translation_emb.parquet')

# %% [markdown]
# Write data into structured folders.

# %% [markdown]
# This part of code allows to partition dataframe into daily frequency and have a same structure as English file.

# %%
# Create the folder to store the monthly data
os.makedirs("/mnt/live/user/yzhong/Chinese_news_data_t", exist_ok=True)

# Read the data
df = pd.read_parquet("/mnt/research-live/user/yzhong/bloomberg_news_chinese_trickers_translation_emb.parquet")

# Extract year and month from the 'date' column
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df['day'] = pd.DatetimeIndex(df['date']).day


for year in df['year'].unique():
    year_folder_path = os.path.join("/mnt/live/user/yzhong/Chinese_news_data_t", str(year))
    os.makedirs(year_folder_path, exist_ok=True)
    for month in df.loc[df['year'] == year, 'month'].unique():
        month_folder_path = os.path.join("/mnt/live/user/yzhong/Chinese_news_data_t",str(year), str(month))
        os.makedirs(month_folder_path, exist_ok=True)
        #print(month_folder_path)
        for day in df.loc[(df['year'] == year)&(df['month'] == month), 'day'].unique():
            #print(day)
            day_df = df.loc[(df['year'] == year) & (df['month'] == month)&(df['day'] == day)]
            del day_df['year']
            del day_df['month']
            del day_df['day']
            filename = f"bloomberg_news_chinese_{str(year)}_{str(month)}_{str(day)}.parquet"
            filepath = os.path.join(month_folder_path, filename)
            day_df.to_parquet(filepath)

# %% [markdown]
# ## English news data

# %% [markdown]
# ### Obtain the embeddings for all the English data

# %%
folder_path = "/mnt/live/user/yzhong/English_news_data"
all_files = []
for year_folder in os.listdir(folder_path):
    year_path = os.path.join(folder_path, year_folder)
    if os.path.isdir(year_path):
        for month_folder in os.listdir(year_path):
            month_path = os.path.join(year_path, month_folder)
            if os.path.isdir(month_path):
                for file_name in os.listdir(month_path):
                    if file_name.endswith(".parquet"):
                        file_path = os.path.join(month_path, file_name)
                        df = pd.read_parquet(file_path)
                        df=df.reset_index().rename(columns={'index': 'id'})
                        df.loc[:,"headline"] = df.headline.apply(lambda x: clean_str(x))
                        ds = Dataset.from_dict(df)
                        cols_to_remove = ds.column_names
                        cols_to_remove.remove("headline")
                        cols_to_remove.remove("id")
                        ds_e=ds.remove_columns(cols_to_remove)
                        ds_e = ds_e.map(lambda x: compute_length(x, text='headline'), batched=True).sort('length', reverse=True)
                        ds_e = ds_e.map(lambda x: sentence_embeddings(x, model,text='headline'), batched=True, batch_size=batch_size).sort('id')
                        headline_input_ids=ds_e['embeddings']
                        df['embedding'] = headline_input_ids
                        df.to_parquet(file_path)

# %% [markdown]
# ## Matching

# %%
def get_bloomberg_news(lang, date):
    '''
    Get Bloomberg news data, dropping rows with null ticker and headline values.
    Add a column 'id' for further resorting the data 

    Parameters:
    lang (str): The language of the news articles. Either 'English' or 'Chinese'.
    date (str): The date of the news articles in the format 'YYYY/MM/DD'.
    Returns:
    bloomberg news datast English/Chinese simplified
    ''' 
    # Load the news data for the specified language and date, drop rows with null ticker values, and reset the index
    if lang=='English':
        df = get_bloomberg_english_news(date).dropna(subset=['headline', 'tickers']).reset_index(drop=True).reset_index().rename(columns={'index': 'id'})
    elif lang=='Chinese':
        df = get_bloomberg_chinese_news(date).dropna(subset=['headline', 'tickers']).reset_index(drop=True).reset_index().rename(columns={'index': 'id'})
    else:
        raise ValueError("Invalid language. Must be either 'English' or 'Chinese'.")
    # Save the data to file in parquet format
    return df

# %%
with open('/mnt/research-live/user/yzhong/english_titles_0417.txt', 'w') as f:
    for row in df_e.itertuples():
        f.write(str(row.headline) + '\n')
        f.write(str(row.tickers) + '\n')

# %%
def preprocess_chinese_headline(string):
    string = add_chinese_period(string)
    string = remove_special_chars(string)
    string = remove_space(string)
    string=full_to_half(string)
    return string

# %%
def laser_cosine(chinese_sentences,english_sentences,laser):
    chinese_emb=laser.embed_sentences(chinese_sentences,lang='zh')
    english_emb=laser.embed_sentences(english_sentences,lang='en')
    c=cosinus_similarity(chinese_emb, english_emb)
    return c

# %%
# for old version of numpy 
np.object = object    
np.bool = bool  
np.float = float  
np.int = int    
np.typeDict =np.sctypeDict

# %%
def prepare_translation_dataset(df,model, lg='chinese'):
    ds = model.prepare_dataset(df, task_type='translation', lg=lg)
    return ds
def prepare_embedding_dataset(df,model, lg):
    ds = model.prepare_dataset(df, task_type='sentence_embedding', lg=lg)
    return ds
def translation(df_c, model,device,batch_size):
    ds = prepare_translation_dataset(df_c,model)
    ds = ds.map(lambda x: model.translate(x,device,text='headline'), batched=True, batch_size=batch_size).sort('id')  # return new dataset
    return ds['translation']
def sentence_embeddings(ds,model, batch_size,lg):
    if lg !='english':  
        ds = ds.map(lambda x: model.sentence_embeddings(x, text='translation'), batched=True, batch_size=batch_size).sort('id')
    else :  
        ds = ds.map(lambda x: model.sentence_embeddings(x, text='headline'), batched=True, batch_size=batch_size).sort('id')
    return ds['embeddings']

def translation_embedding(df_c, df_e,model,device, batch_size_translate, batch_size_embeddings):
    ds_c = prepare_translation_dataset(df_c,model)
    translations = translation(ds_c, model,device,batch_size_translate)
    df_c['translation'] = translations
    ds_sc = prepare_embedding_dataset(df_c,model,lg='chinese')
    ds_se = prepare_embedding_dataset(df_e,model,lg='english')
    chinese_emb = sentence_embeddings(ds_sc,model, batch_size_embeddings,lg='chinese')
    df_c['embedding'] = chinese_emb
    english_emb = sentence_embeddings(ds_se, model,batch_size_embeddings,lg='english')
    df_e['embedding'] = english_emb
    return df_c, df_e


def translation_cosine(chinese_emb, english_emb):
    c = F.normalize(torch.tensor(chinese_emb).unsqueeze(0)) @ F.normalize(torch.tensor(english_emb)).t()
    return c.numpy()

# %%
class TranslationSentenceEmbeddingPipeline:
    """
    A class for performing translation and sentence embedding tasks using pretrained models.
    """
    CACHE_DIR = config_['model_dir']  # constant for cache directory
    MAX_LENGTH = 512 # constant for maximum sequence length
    def __init__(
        self,
        translation_model_name: str,
        sentence_embedding_model_name: str,
        device 
    ) -> None:
        """
        Initialize the TranslationSentenceEmbeddingPipeline class.

        Args:
            translation_model_name: The name of the pretrained translation model to use.
            sentence_embedding_model_name: The name of the pretrained sentence embedding model to use.
            device: The device to use for computations (e.g. 'cpu' or 'cuda').
        """
        self.translation_model = AutoModelForSeq2SeqLM.from_pretrained(
            translation_model_name,
            cache_dir=self.CACHE_DIR
        ).to(device)
        self.translation_tokenizer = AutoTokenizer.from_pretrained(
            translation_model_name,
            use_fast=True,
            cache_dir=self.CACHE_DIR
        )
        self.sentence_embedding_model = SentenceTransformer(
            sentence_embedding_model_name,
            device=device,
            cache_folder=self.CACHE_DIR
        )

    def compute_length(
        self,
        batch,
        text: str = 'headline'
    ) -> dict:
        """
        Compute the length of each sentence in a batch.
        """
        return {'length': [len(item) for item in batch[text]]}

    def prepare_dataset(
        self,
        df,
        task_type: str,
        lg: str 
    ) -> Dataset:
        """
        Prepare the input data for a translation or sentence embedding task.
        Args:
            df: A pandas DataFrame containing the input data.
            task_type: The type of task to perform ('translation' or 'sentence_embedding').
            lg: The language of the input text (default is 'chinese').
        Returns:
            A Hugging Face Dataset object containing the preprocessed input data.
        """
        if task_type == 'translation':
            # Implementation for preparing translation dataset
            ds = Dataset.from_dict({
                "id": df["id"],
                "headline": df["headline"]
               # ,"length": df["headline"].str.len()
                
            })
            ds = ds.map(lambda x: {
                'headline': preprocess_chinese_headline(x['headline']),
                'id': x['id']
            })
            ds = ds.map(lambda x: self.compute_length(x, text='headline'), batched=True).sort('length', reverse=True)
           
        elif task_type == 'sentence_embedding':
            # Implementation for preparing sentence embedding dataset
            if lg != 'english':
                col = 'translation'
            else:
                col = 'headline'
            ds = Dataset.from_dict({
                "id": df["id"],
                col: df[col]
            })
            ds = ds.map(lambda x: {
                col: clean_str_english(x[col]),
                'id': x['id']
            })
            ds = ds.map(lambda x: model.compute_length(x, text=col), batched=True).sort('length', reverse=True)
        return ds
    
    def translate(self,batch,device,text='headline'):
        tokenized_batch = self.translation_tokenizer(
            batch[text],
            padding="longest",
            truncation=True,
            max_length=self.MAX_LENGTH,
            return_tensors="pt"
        )
        inputs = {
            k: v.to(device) for k, v in tokenized_batch.items() 
            if k in self.translation_tokenizer.model_input_names
        }
        with torch.no_grad():
            translation = self.translation_model.generate(**inputs)
        return {
        'translation': self.translation_tokenizer.batch_decode(
            translation, skip_special_tokens=True
        )
    }

    def sentence_embeddings(self, batch, text='headline'):
        with torch.no_grad():
            embeddings = self.sentence_embedding_model.encode(batch[text])
        return {'embeddings': embeddings}

# %%
df_c=pd.read_parquet('/mnt/research-live/user/yzhong/Chinese_news_data_bloomberg/2023/04/bloomberg_news_Chinese_2023_04_17.parquet')
df_e=pd.read_parquet('/mnt/research-live/user/yzhong/English_news_data_bloomberg/2023/04/bloomberg_news_English_2023_04_17.parquet')

# %%
def find_matches_tickers(tickers,last_update,df_e):
    # Create an empty list to store matches
    matches = []
    # Find all rows in df_e that contain any of the tickers and have a delay of less than 2 hours
    con2 = (abs((last_update - df_e['last_update']).dt.total_seconds() / 60) < 120) #delay_condition
    ticker_matches = df_e[(df_e['tickers'].str.contains('|'.join(tickers))) & con2]
    # Append the ticker_matches to the list of matches
    matches.append(ticker_matches)
    # Concatenate all the matches and reset the index
    matches = pd.concat(matches).reset_index(drop=True)
    matches['delay']=abs((last_update - matches['last_update']).dt.total_seconds()) /60
    return matches

def assign_match_headline_cos(df_c,row,matrix,matches):
    sorted_indices = np.argsort(-matrix, axis=1)
    max_cos_indice = sorted_indices[0][0]
    df_c.at[row.Index, 'match_cs_headline'] = matches.at[max_cos_indice, 'headline']
    df_c.at[row.Index, 'match_cs_cos'] = matrix[0][max_cos_indice]
    df_c.at[row.Index, 'match_cs_date'] = matches.at[max_cos_indice, 'last_update']
    df_c.at[row.Index, 'match_cs_suid'] = matches.at[max_cos_indice, 'suid']
    
def assign_match_headline_faiss(df_c,row,index,score,matches):
    #sorted_indices = np.argsort(-matrix, axis=1)
    #max_cos_indice = sorted_indices[0][0]
    df_c.at[row.Index, 'match_faiss_headline'] = matches.at[index, 'headline']
    df_c.at[row.Index, 'match_faiss_cos'] = score
    df_c.at[row.Index, 'match_faiss_date'] = matches.at[index, 'last_update']
    df_c.at[row.Index, 'match_faiss_suid'] = matches.at[index, 'suid']
    




def assign_match_delay(matches, df_c, row):
    min_delay_index = matches['delay'].idxmin()
    df_c.at[row.Index, 'match_delay_headline'] = matches.at[min_delay_index, 'headline']
    df_c.at[row.Index, 'match_delay_date'] = matches.at[min_delay_index, 'last_update']
    df_c.at[row.Index, 'match_delay_suid'] = matches.at[min_delay_index, 'suid']

# %%
def match_headline_test(method):
    df_c=pd.read_parquet('/mnt/research-live/user/yzhong/Chinese_news_data_bloomberg/2023/04/bloomberg_news_Chinese_2023_04_17.parquet')
    df_e=pd.read_parquet('/mnt/research-live/user/yzhong/English_news_data_bloomberg/2023/04/bloomberg_news_English_2023_04_17.parquet')
    df_c['match']=False
    if method =='Laser':
        laser = Laser()
    elif method =='Translation':
        device = "cuda:0" if torch.cuda.is_available() else "cpu" 
        model = TranslationSentenceEmbeddingPipeline(config_['TRANSLATION_MODEL'], config_['SENTENCE_TRANSFORMER'],device)
        df_c,df_e=translation_embedding(df_c, df_e,model,device, batch_size_translate=32, batch_size_embeddings=256)
    else:
        raise ValueError("Invalid method. Must be either 'Laser' or 'Translation'.")
    for row in df_c.itertuples():
        tickers = list(set(row.tickers.split(', '))) # get all the unique tickers in a list
        last_update=row.last_update
        matches=find_matches_tickers(tickers,last_update,df_e)
        if len(matches) > 0:
            df_c.at[row.Index, 'match'] = True
            #assign_match_delay(matches, df_c, row)
            if method=='Laser':
                chinese_sentences=row.headline
                english_sentences=matches.headline.to_list()
                c=laser_cosine(chinese_sentences,english_sentences,laser)
            if method == 'Translation':
                chinese_emb=row.embedding
                english_emb=matches.embedding.to_list()
                c=translation_cosine(chinese_emb,english_emb)
            assign_match_headline_cos(df_c,row,c,matches)
            pass
        pass
    
    return df_c

# %%
def laser_faiss(chinese_sentence,english_sentences,laser):
    '''
    '''
    embeddings = laser.embed_sentences(english_sentences,lang='en')
    # Normalize embeddings to unit length
    normalized_embeddings = embeddings / np.linalg.norm(embeddings, axis=1)[:, None]
    # Build an index using faiss
    index = faiss.IndexFlatIP(normalized_embeddings.shape[1])
    index.add(normalized_embeddings)
    # Perform a similarity search
    query = chinese_sentence
    query_embedding = laser.embed_sentences([query], lang=['zh'])[0]
    normalized_query_embedding = query_embedding / np.linalg.norm(query_embedding)
    D, I = index.search(normalized_query_embedding.reshape(1, -1), k=1)
    return I[0][0], D[0][0]

# %%
df_c=pd.read_parquet('/mnt/research-live/user/yzhong/Chinese_news_data_bloomberg/2023/04/bloomberg_news_Chinese_2023_04_17.parquet')
df_e=pd.read_parquet('/mnt/research-live/user/yzhong/English_news_data_bloomberg/2023/04/bloomberg_news_English_2023_04_17.parquet')

# %%
def match_headline_test_avectickers(df_c,df_e,method):

    #df_c['match']=False
    if method =='Laser':
        laser = Laser()
    elif method =='Translation':
        device = "cuda:0" if torch.cuda.is_available() else "cpu" 
        model = TranslationSentenceEmbeddingPipeline(config_['TRANSLATION_MODEL_ADVANCE'], config_['SENTENCE_TRANSFORMER'],device)
        df_c,df_e=translation_embedding(df_c, df_e,model,device, batch_size_translate=32, batch_size_embeddings=256)
    else:
        raise ValueError("Invalid method. Must be either 'Laser' or 'Translation'.")
    for row in df_c.itertuples():
        tickers = list(set(row.tickers.split(', '))) # get all the unique tickers in a list
        last_update=row.last_update
        matches=find_matches_tickers(tickers,last_update,df_e)
        if len(matches) > 0:
            df_c.at[row.Index, 'match'] = True
            #assign_match_delay(matches, df_c, row)
            if method=='Laser':
                chinese_sentence=preprocess_chinese_headline(row.headline) #row.headline
                english_sentences=matches.headline.apply(lambda x: clean_str_english(x)).to_list() 
                index,score=laser_faiss(chinese_sentence,english_sentences,laser)
                #c=laser_cosine(chinese_sentence,english_sentences,laser)
            if method == 'Translation':
                chinese_emb=row.embedding
                english_emb=matches.embedding.to_list()
                c=translation_cosine(chinese_emb,english_emb)
            assign_match_headline_faiss(df_c,row,index,score,matches)
            #assign_match_headline_cos(df_c,row,c,matches)
            pass
        pass
    
    return df_c

# %%
df_c=match_headline_test_avectickers(df_c,df_e,'Laser')

# %%
with open('/mnt/research-live/user/yzhong/match_similarity_laser_0417.txt', 'w') as f:
    for row in df_c.itertuples():
        f.write(str(row.match_faiss_headline) + '\n')

# %%
with open('/mnt/research-live/user/yzhong/match_similarity_translation_0417.txt', 'w') as f:
    for row in df_t.itertuples():
        f.write(str(row.translation) + '\n')

# %%
df_t=match_headline_test_avectickers('Translation')

# %%
with open('/mnt/research-live/user/yzhong/match_similarity_laser_0417.txt', 'w') as f:
    for row in df_c.itertuples():
        f.write(str(row.match_cs_headline) + '\n')

# %%
def match_max_cos (c,df_c,df_e):
    # Get the indices of the maximum value for each row
    max_indices = np.argmax(c, axis=1)
    # Create an empty dataframe to store the closest neighbour for each sentence
    sim_df = pd.DataFrame(columns=['id', 'Sim1', 'tickers1', 'date1', 'cos1'])
    # Loop over the rows of the `max_indices` array
    for i, max_index in enumerate(max_indices):
    # Get the index of the current row
        index = i
        # Get the corresponding row from `df_e`
        match = df_e.loc[df_e['id'] == max_index].reset_index(drop=True)
        # Create a new row to add to `sim_df`
        new_row = {'id': index, 'Sim1': match['headline'][0], 'tickers1': match['tickers'][0], 'date1': match['last_update'][0], 'cos1': c[i][max_index]}
        # Add the new row to `sim_df`
        sim_df = sim_df.append(new_row, ignore_index=True)
    merged_df = pd.merge(df_c, sim_df, on='id')

    return merged_df

# %%
def match_headline_test_sanstickers(df_c,df_e,method):
    #df_c['match']=False
    if method =='Laser':
        laser = Laser()
        chinese_sentences=df_c.headline.apply(lambda x: preprocess_chinese_headline(x)).to_list()
        english_sentences=df_e.headline.apply(lambda x: clean_str_english(x)).to_list()
        c=laser_cosine(chinese_sentences,english_sentences,laser)
        df_c=match_max_cos (c,df_c,df_e)
    elif method =='Translation':
        device = "cuda:0" if torch.cuda.is_available() else "cpu" 
        model = TranslationSentenceEmbeddingPipeline(config_['TRANSLATION_MODEL_ADVANCE'], config_['SENTENCE_TRANSFORMER'],device)
        df_c,df_e=translation_embedding(df_c, df_e,model,device, batch_size_translate=32, batch_size_embeddings=256)
        c=cosinus_similarity (df_c['embedding'].to_list(), df_e['embedding'].to_list())
        df_c=match_max_cos (c,df_c,df_e)
    return df_c

# %%
df_c=match_headline_test_sanstickers(df_c,df_e,'Laser')

# %%
with open('/mnt/research-live/user/yzhong/english_titles_0417.txt', 'w') as f:
    for row in df_e.itertuples():
        f.write(str(row.headline) + '\n')

# %%
df_c[df_c['headline']=='汇市/利率简报:美元连续第二日走高 升息预期提振美债收益率'].body.to_list()
# Out:
# ['\n记者 Anya Andrianova\n     【彭博】-- 美元连续第二天上涨,美联储进一步收紧政策的可能性\n提升了美国国债收益率。所有G-10货币均兑美元下跌。\n     重点关注:\n\n  * 中国GDP\n  * 印尼央行利率决定\n\n     前日市场(截至纽约时间下午5点左右):\n\n  * 彭博美元即期指数上涨0.4%\n    * 对冲基金押注美元近三年来最长的周度跌势将\n      逆转\n  * 亚太区G-10货币\n    * 美元/日元涨0.5%至134.43\n    * 澳元/美元基本持平,\n      报0.6705\n    * 新西兰元/美元下跌0.3%至0.6186\n  * 10年期美国国债收益率上升8.2\n    个基点至3.59%。5年和30年期国债收益率差收窄1.4个基点至11.2个基点\n\n     前日人民币市场概况:\n\n  * 离岸人民币兑美元收盘下跌0.14%,报6.8827元\n  * 在岸人民币兑美元北京时\n    间16:30官方收盘价报6.8717元,夜盘最后成交于6.8817元,下跌0.18%\n  * 人\n    民币兑美元中间价报6.8679元,市场预测均值为6.8686元\n  * 近5日中间价较\n    预测均值平均偏强约7点,近20日中间价较预测均值平均偏强约7点\n\n     当日图表\n     要闻:\n\n  * 中国一季度经济数据即将发布 不均衡迹象或继续存在 \n  * 里士满联储行长:\n    希望看到更多显示通胀回落的证据\n  * 纽约联储调查:美国劳动力最低薪资要\n    求达到创纪录的76,000美元\n  * 第一信托银行难觅买主 问题出在那群富人客\n    户身上\n  * 美国3个月期国库券中标收益率超5% 创克林顿时期以来最高值 \n  * 嘉\n    信理财客户存款同比大降 高管自信能挺过暴风雨 \n  * 台湾将从美国采购400\n    枚岸基版“鱼叉”反舰导弹\n\n     重要观点:\n\n  * 美联储降息前景扑朔 高盛和道明各执一词\n  * IMF:中国将成为未来五年全球\n    最大经济增长源 贡献率是美国两倍\n  * 华尔街知名空头Wilson:债券收益率\n    上升或致标普500指数创新低\n  * 分析师:贝莱德的资管规模未来五年将突\n    破15万亿美元\n\n     周一数据:\n\n  * 纽约州制造业活动意外地出现五个月来首次扩张\n  * 美国住宅建筑商信心指数\n    连续第四个月上升\n\n     经济数据日程(预估为彭博调查所得预估中值;北京时间)\n\n  * 10:00:中国第一季度GDP同比(预估为4.0%,前季度为2.9%)\n  * 10:00:中\n    国1-3月工业增加值同比(预估为3.5%,1-2月为2.4%)\n  * 10:00:中国3月工\n    业增加值同比(预估为4.3%)\n  * 10:00:中国1-3月社会消费品零售总额同比\n    (预估为3.7%,1-2月为3.5%)\n  * 10:00:中国3月社会消费品零售总额同比\n    (预估为7.5%)\n  * 10:00:中国1-3月不含农户固定资产投资同比(预估\n    为5.7%,1-2月为5.5%)\n  * 10:00:中国1-3月房地产开发投资同比(预估\n    为-4.7%,1-2月为-5.7%)\n  * 10:00:中国1-3月住宅销售额同比(前值\n    为3.5%)\n  * 10:00:中国3月调查失业率(预估为5.5%,前值\n    为5.6%)\n  * 14:00:英国3月申领失业救济金人数(前值为-1.12万)\n  * 14:00:\n    英国2月ILO失业率(预估为3.7%,前值为3.7%)\n  * 20:30:美国3月新宅开工\n    年率(预估为140万,前值为145万)\n  * 20:30:美国3月建筑许可年率(预估\n    为145万,前值为152.4万)\n  * 20:30:加拿大3月消费价格同比(预估\n    为4.3%,前值为5.2%)\n\n     央行和政府动态(北京时间)\n\n  * 09:30:澳大利亚央行4月份货币政策会议纪要\n  * 10:00:中国国新办就2023\n    年一季度国民经济运行情况举行发布会\n  * 15:20:印尼央行利率决定(预估\n    为5.75%,现值为5.75%)\n  * 16:30:欧洲央行管委、葡萄牙央行行长Centeno\n    讲话\n  * 23:00:加拿大央行行长Macklem讲话\n  * 19日01:00:美联储理事Bowman\n    讲话\n\n     债券发行日程(北京时间)\n\n  * 09:30:贵州省政府拟发76.414亿元30年专项债券、88.868亿元7年一般债\n    券\n  * 10:30:黑龙江省政府拟发90亿元10年专项债券\n  * 11:30:香港拟发190亿\n    港元182天期票据、20亿港元28天期票据、625.8亿港元91天期票\n    据\n  * 14:00:山东省政府拟发1.15亿元7年专项债券、6.9亿元7年专项债\n    券、1.37亿元10年专项债券等\n  * 15:00:内蒙古自治区政府拟发8.37亿元10\n    年专项债券、1.41亿元10年专项债券、6.78亿元15年专项债券等\n  * 16:00:\n    辽宁省政府拟发150亿元10年专项债券\n  * 17:00:英国拟发22.5亿英镑2053年\n    到期国债\n  * 18:30:欧洲金融稳定机制(ESM)拟发11亿欧元182天期票\n    据\n  * 23:30:美国拟发340亿美元52周期国库券\n\n     原文标题FX/RATES DAYBOOK ASIA: Dollar Gains Further on Fed\nHike Bets\n\n--联合报道 Robert Fullem.\n\n欲联系中文编译请洽:\nLynn Chen Toronto lchen195@bloomberg.net\n欲联系记者请洽:\nAnya Andrianova New York aandrianova@bloomberg.net\n欲联系英文编辑请洽:\nBenjamin Purvis bpurvis@bloomberg.net\nLisa Wolfson、William Selway\n']

# %%
df_e
# Out:
#         id          suid             last_update language  analyst  \
# 0        0  ROL7ICDWLU68 2023-04-17 14:12:52.026  ENGLISH    False
# 1        1  RS0U67DWRGG0 2023-04-17 22:00:00.201  ENGLISH    False
# 2        2  RT09ZADWRGG0 2023-04-17 12:45:01.518  ENGLISH    False
# 3        3  RT0TAFDWX2PS 2023-04-17 06:20:01.610  ENGLISH    False
# 4        4  RT40NFGFR4SG 2023-04-17 06:30:06.200  ENGLISH    False
# ...    ...           ...                     ...      ...      ...
# 2363  2363  RTA8T1T0AFB4 2023-04-17 23:22:07.866  ENGLISH    False
# 2364  2364  RTA956GFLIIO 2023-04-17 23:27:06.243  ENGLISH     True
# 2365  2365  RTA9A6GFA9Z4 2023-04-17 23:30:06.133  ENGLISH     True
# 2366  2366  RTAA44GFLIIO 2023-04-17 23:48:04.082  ENGLISH     True
# 2367  2367  RTAAG46RV5DS 2023-04-17 23:55:16.043  ENGLISH    False
#
#             date                                            tickers  \
# 0     2023-04-17                                         TSLA, TSLA
# 1     2023-04-17  2330@TT, 2330@TT, 2317@TT, 2317@TT, 2330@TT, 2...
# 2     2023-04-17  GS, UBSG@SW, UBSG@SW, UBSG@SW, UBSG@SW, BX, GS...
# 3     2023-04-17                                            ASHM@LN
# 4     2023-04-17  UCG@IM, UCG@IM, UCG@IM, UCG@IM, UCG@IM, UCG@IM...
# ...          ...                                                ...
# 2363  2023-04-17  ANZ@AU, SGP@AU, SGP@AU, SGP@AU, NAB@AU, NAB@AU...
# 2364  2023-04-17                                         INCY, INCY
# 2365  2023-04-17                                           WBA, WBA
# 2366  2023-04-17                                         ATER, ATER
# 2367  2023-04-17                 GAPB@MM, GAPB@MM, GAPB@MM, GAPB@MM
#
#                                               eqt_codes  \
# 0                                      TSLA_UW, TSLA_UW
# 1     TSM_UN, 2330_TT, 2317_TT, HHPD_LI, TSM_UN, 233...
# 2     GS_UN, UBSN_SW, UBS_UN, UBS_US, UBSG_VX, BX_US...
# 3                                               ASHM_LN
# 4     UC_IM, UCR_IM, UC_R_IM, UCGAA_IM, UCGAZ_IM, CR...
# ...                                                 ...
# 2363  ANZ_AU, SGP_AU, SGPNA_AU, SGPNF_AU, NAB_AU, NA...
# 2364                                   INCY_UQ, INCY_UQ
# 2365                                     WAG_UN, WAG_UN
# 2366                                     MWK_US, MWK_US
# 2367                   PAC_UN, GAPB_MM, PAC_UN, GAPB_MM
#
#                                                  topics  \
# 0     BIZNEWS, MSCIWORLD, NORTHAM, EQTY, DOT, CONSD,...
# 1     UNREST, METALKEY, BIZNEWS, CNG, MSCIWORLD, NOR...
# 2     CORPFIN, BIZNEWS, BFWLOAEU, EQTY, FIN, BUSINES...
# 3     ERNMAIN, BIZNEWS, MSCIWORLD, EQTY, FIN, ERN, A...
# 4     BELG, METALKEY, GRE, BIZNEWS, MSCIWORLD, ECOST...
# ...                                                 ...
# 2363  CORPFIN, BIZNEWS, MSCIWORLD, FIN, FIRPT, SYNBO...
# 2364  ANACHANGE, BIZNEWS, ANA, MSCIWORLD, NORTHAM, E...
# 2365  ANACHANGE, BIZNEWS, ANA, MSCIWORLD, NORTHAM, E...
# 2366  ANACHANGE, BIZNEWS, ANA, EQTY, BUSINESS, ANAMO...
# 2367  MINT, BIZNEWS, MSCIWORLD, SVC, NORTHAM, CST, C...
#
#                                                headline  \
# 0     Tesla Reports Another Fatal US Crash Involving...
# 1     Why Taiwan’s Vote Matters From Beijing to Wash...
# 2     CVC Targets Wealthy Individuals in European Pr...
# 3     Ashmore Clients Pull $1.1 Billion in Seventh Q...
# 4     Eurozone 3M Yield at 3.50% by End-2Q23 vs 3.60...
# ...                                                 ...
# 2363  LAUNCH: Stockland Trust A$ 7Y Bmark at Swaps +...
# 2364  Incyte Rated New Hold at Baptista Research; PT...
# 2365  Walgreens Boots Rated New Hold at Baptista Res...
# 2366                     Aterian Cut to Neutral at BTIG
# 2367  *GAP AIRPORTS 1Q OPER INCOME MXN4.08B, EST. MX...
#
#                                                    body
# 0     \nBy Keith Laing\n     (Bloomberg) -- Tesla In...
# 1     \nBy Cindy Wang and Samson Ellis\n     (Bloomb...
# 2     \nBy Silas Brown\n     (Bloomberg) -- CVC Capi...
# 3     \nBy Nishant Kumar\n     (Bloomberg) -- Ashmor...
# 4     \nBy Harumi Ichikura\n     (Bloomberg) -- The ...
# ...                                                 ...
# 2363  \nBy Finbarr Flynn\n     (Bloomberg) -- STOCKL...
# 2364  \nBy Bloomberg Automation\n     (Bloomberg) --...
# 2365  \nBy Bloomberg Automation\n     (Bloomberg) --...
# 2366  \nBy Bloomberg Automation\n     (Bloomberg) --...
# 2367                      \n-0- Apr/17/2023 23:55 GMT\n
#
# [2368 rows x 11 columns]

# %%
def find_star (df):
    return ( df['headline'].str.contains(r'^\*[\u4e00-\u9fff0-9a-zA-Z].*'))
def get_TF(x, info_list):
    return any([True for i in info_list if i in str(x)])
    
def find_words(df, col_name='body', my_words=None):
    
    if my_words is None:
        my_words = ['原文标题','彭博自动新闻','原文標題']
        return (df[col_name].apply(lambda x: get_TF(x, my_words)))        
#df=df_sim.copy(deep=True)
# mask1=find_star(df_c)
# mask2=find_words(df_c)
# df_c['contains_star']=mask1
# df_c['contains_words']=mask2
# df_c['Only_Ch']= (~mask1) & (~mask2)

# %%
def match_headline(date,method):
    df_c=get_bloomberg_news('Chinese', date)
    df_e=get_bloomberg_news('English', date)
    df_c['match']=False
    if method =='Laser':
        laser = Laser()
    elif method =='Translation':
        device = "cuda:0" if torch.cuda.is_available() else "cpu" 
        model = TranslationSentenceEmbeddingPipeline(config_['TRANSLATION_MODEL'], config_['SENTENCE_TRANSFORMER'],device)
        df_c,df_e=translation_embedding(df_c, df_e,model,device, batch_size_translate=32, batch_size_embeddings=256)
    else:
        raise ValueError("Invalid method. Must be either 'Laser' or 'Translation'.")
    for row in df_c.itertuples():
        tickers = list(set(row.tickers.split(', '))) # get all the unique tickers in a list
        last_update=row.last_update
        matches=find_matches_tickers(tickers,last_update,df_e)
        if len(matches) > 0:
            df_c.at[row.Index, 'match'] = True
            assign_match_delay(matches, df_c, row)
            if len(matches) >1:
                if method=='Laser':
                    chinese_sentences=row.headline
                    english_sentences=matches.headline.to_list()
                    c=laser_cosine(chinese_sentences,english_sentences,laser)
                if method == 'Translation':
                    chinese_emb=row.embedding
                    english_emb=matches.embedding.to_list()
                    c=translation_cosine(chinese_emb,english_emb)
                assign_match_headline_cos(df_c,row,c,matches)
                pass
            pass
    
    return df_c

# %%
with open('/mnt/research-live/user/yzhong/headline_0417.txt', 'w') as f:
    for row in df_t.itertuples():
        f.write(str(row.match_delay_headline) + '\n')

# %%
def Save_bloomberg_news(lang, date):
    '''
    Save Bloomberg news data to a file in parquet format, dropping rows with null ticker values.

    Parameters:
    lang (str): The language of the news articles. Either 'English' or 'Chinese'.
    date (str): The date of the news articles in the format 'YYYY/MM/DD'.

    Returns:
    None
    '''
    # Extract year, month, and day from the date string
    year, month, day = date.split('/')
    
    # Construct the folder path where the data will be saved
    folder_path = f'{DATA_PATH}{lang}_news_data_bloomberg/{year}/{month}'
    
    # Create the folder if it doesn't exist
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    
    # Construct the file name and file path where the data will be saved
    file_name = f'bloomberg_news_{lang}_{year}_{month}_{day}.parquet'
    file_path = os.path.join(folder_path,file_name)
    
    # Load the news data for the specified language and date, drop rows with null ticker values, and reset the index
    if lang=='English':
        df = get_bloomberg_english_news(date).dropna(subset=['headline', 'tickers']).reset_index(drop=True).reset_index().rename(columns={'index': 'id'})
    elif lang=='Chinese':
        df = get_bloomberg_chinese_news(date).dropna(subset=['headline', 'tickers']).reset_index(drop=True).reset_index().rename(columns={'index': 'id'})
    else:
        raise ValueError("Invalid language. Must be either 'English' or 'Chinese'.")
    # Save the data to file in parquet format
    df.to_parquet(file_path)

def save_news(date):
    Save_bloomberg_news('English', date)
    Save_bloomberg_news('Chinese', date)

# %%
with open('/mnt/research-live/user/yzhong/match_similarity.txt', 'w') as f:
    for row in df_c.itertuples():
        f.write(str(row.headline) + '\n')
        f.write(str(row.translation) + '\n')
        f.write(f' Sim: {row.delay} {row.sim}   ' + '\n')
        f.write(f' Sim_cos: {row.delay_cos} {row.sim_cos} ' + '\n')

# %% [markdown]
# ## Process with all dataset

# %%
df= pd.read_parquet('/mnt/research-live/user/yzhong/Chinese_news_data_t/2011/4/bloomberg_news_chinese_2011_4_5.parquet')

# %%
df= pd.read_parquet('/mnt/research-live/user/yzhong/English_news_data/2011/04/bloomberg_news_english_2011_04_05.parquet')

# %%
def assign_match_headline_cos(df_c,row,matrix,matches):

    ''' Assign match headline and cosine similarity values 

    Inputs:
    - df_c: DataFrame containing Chinese news headlines
    - row: current row of the DataFrame being processed
    - matrix: matrix containing cosine similarity scores between Chinese and English sentences
    - matches: DataFrame containing English news headlines that match the tickers and last_update of the current row

    Outputs: None
    '''
    sorted_indices = np.argsort(-matrix, axis=1)
    max_cos_indice = sorted_indices[0][0]
    df_c.at[row.Index, 'match_cs_headline'] = matches.at[max_cos_indice, 'headline']
    df_c.at[row.Index, 'match_cs_cos'] = matrix[0][max_cos_indice]
    df_c.at[row.Index, 'match_cs_date'] = matches.at[max_cos_indice, 'last_update']
    df_c.at[row.Index, 'match_cs_suid'] = matches.at[max_cos_indice, 'suid']

def match (df_c,df_e):
    ''' Find English news headlines that match the Chinese news headlines based on tickers, last_update date and cosine similarity

    Inputs:
    - df_c: DataFrame containing Chinese news headlines
    - df_e: DataFrame containing English news headlines

    Outputs:
    - df_c: Updated DataFrame with added columns for match headline cosine similarity, date, and suid
    '''
    # Set the match column in the DataFrame df_c to False for all rows
    df_c['match'] = False
    # Initialize the laserembeddings object
    laser = Laser()
    # Iterate through all rows in the DataFrame df_c
    for row in df_c.itertuples():
        # Get all the unique tickers in a list
        tickers = list(set(row.tickers.split(', ')))
        # Get the last update value for the row
        last_update = row.last_update
        # Find matches for the tickers and last_update value
        matches = find_matches_tickers(tickers, last_update, df_e)
        # If there are any matches, set the match column to True for the current row and assign match headline cosine similarity values
        if len(matches) > 0:
            df_c.at[row.Index, 'match'] = True
            chinese_sentences = row.headline
            english_sentences = matches.headline.to_list()
            cosine_similarities = laser_cosine(chinese_sentences, english_sentences,laser)
            assign_match_headline_cos(df_c, row, cosine_similarities, matches)
        pass 
    # Return the updated DataFrame df_c
    return df_c

# %%
# Define the paths to the Chinese and English news data folders
chinese_folder_path = '/mnt/research-live/user/yzhong/Chinese_news_data_t'
english_folder_path = '/mnt/research-live/user/yzhong/English_news_data'

# Loop over the Chinese news data folders
for year_folder in os.listdir(chinese_folder_path):
    if os.path.isdir(os.path.join(chinese_folder_path, year_folder)):
        for month_folder in os.listdir(os.path.join(chinese_folder_path, year_folder)):
            for file_name in os.listdir(os.path.join(chinese_folder_path, year_folder,month_folder)):
            # Check if the file is a parquet file and contains the string 'bloomberg_news_chinese'
                if file_name.endswith('.parquet') and 'bloomberg_news_chinese' in file_name:
                   
                    df_c=pd.read_parquet(os.path.join(chinese_folder_path, year_folder,month_folder,file_name))
                    print(os.path.join(chinese_folder_path, year_folder,month_folder,file_name))
                    del df_c['id']
                    df_c=df_c.reset_index().rename(columns={'index': 'id'})
                    #get the file path for the english news
                    year = year_folder
                    month = month_folder
                    month_str = f"{int(month):02d}"
                    day=file_name.split('_')[-1].split('.')[0]
                    day_str=f"{int(day):02d}"
     
                    english_folder_year_month = os.path.join(english_folder_path, year, month_str)

                    if os.path.exists(english_folder_year_month):
                        english_file=os.path.join(english_folder_year_month, f'bloomberg_news_english_{year}_{month_str}_{day_str}.parquet')
                        print(english_file)
                        df_e = pd.read_parquet(english_file) 
                        del df_e['id']
                        df_e=df_e.reset_index().rename(columns={'index': 'id'})
                    match_df=match(df_c,df_e)
                    # create the file path and name
                    file_name = f"/mnt/research-live/user/yzhong/Match_news/bloomberg_news_chinese_matching_{year}_{month_str}_{day_str}.parquet"
                    match_df.to_parquet(file_name)
# Out:
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/11/bloomberg_news_chinese_2018_11_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/11/bloomberg_news_english_2018_11_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/9/bloomberg_news_chinese_2018_9_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/09/bloomberg_news_english_2018_09_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_31.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_31.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/7/bloomberg_news_chinese_2018_7_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/07/bloomberg_news_english_2018_07_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_31.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_31.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/10/bloomberg_news_chinese_2018_10_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/10/bloomberg_news_english_2018_10_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/2/bloomberg_news_chinese_2018_2_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/02/bloomberg_news_english_2018_02_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/6/bloomberg_news_chinese_2018_6_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/06/bloomberg_news_english_2018_06_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_31.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_31.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/3/bloomberg_news_chinese_2018_3_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/03/bloomberg_news_english_2018_03_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_31.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_31.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/8/bloomberg_news_chinese_2018_8_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/08/bloomberg_news_english_2018_08_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/5/bloomberg_news_chinese_2018_5_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/05/bloomberg_news_english_2018_05_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/5/bloomberg_news_chinese_2018_5_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/05/bloomberg_news_english_2018_05_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2018/5/bloomberg_news_chinese_2018_5_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2018/05/bloomberg_news_english_2018_05_12.parquet
# ...
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/4/bloomberg_news_chinese_2014_4_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/04/bloomberg_news_english_2014_04_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_31.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_31.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_26.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_20.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_20.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_6.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_06.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/1/bloomberg_news_chinese_2014_1_13.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/01/bloomberg_news_english_2014_01_13.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_31.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_31.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_5.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_05.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_27.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_27.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_12.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_12.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_19.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_19.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_9.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_09.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_30.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_30.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_25.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_25.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_1.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_01.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_24.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_24.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_28.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_28.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_22.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_22.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_23.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_23.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_21.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_21.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_17.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_17.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_8.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_08.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_16.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_16.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_14.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_14.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_2.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_02.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_15.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_15.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_3.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_03.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_18.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_18.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_11.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_11.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_7.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_07.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_10.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_10.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_4.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_04.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_29.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_29.parquet
# /mnt/research-live/user/yzhong/Chinese_news_data_t/2014/12/bloomberg_news_chinese_2014_12_26.parquet
# /mnt/research-live/user/yzhong/English_news_data/2014/12/bloomberg_news_english_2014_12_26.parquet

# %% [markdown]
# ## Test with LASER

# %% [markdown]
# https://github.com/facebookresearch/LASER

# %%
del df_c['id']
df_c=df_c.reset_index().rename(columns={'index': 'id'})
del df_e['id']
df_e=df_e.reset_index().rename(columns={'index': 'id'})

# %% [markdown]
# #### Using Laser

# %%
from laserembeddings import Laser

laser = Laser()
chinese_sentences=df_c['headline'].to_list()
english_sentences=df_e['headline'].to_list()

# %%
chinese_emb=laser.embed_sentences(chinese_sentences,lang='zh')
english_emb=laser.embed_sentences(english_sentences,lang='en')
english_emb=torch.tensor(english_emb)
chinese_emb=torch.tensor(chinese_emb)

# %% [markdown]
# #### Using translation embedding

# %%
chinese_emb=torch.tensor(df_c['embedding'].to_list())
english_emb=torch.tensor(df_e['embedding'].to_list())

# %% [markdown]
# #### Calculate cosinus similarity

# %%
c=cosinus_similarity (chinese_emb, english_emb)
c=c.numpy()
# Get the indices that would sort each row in descending order
sorted_indices = np.argsort(-c, axis=1) # this will sort in descending values
# Get the indices of the top three values for each row
top_three_indices = sorted_indices[:, :3]
# Create an empty dataframe to store the three closest neighbours for each sentences
sim_df = pd.DataFrame(columns=['id', 'Sim1', 'Sim2', 'Sim3','tickers1','tickers2','tickers3', 'date1', 'date2', 'date3','cos1', 'cos2', 'cos3'])

# Loop over the rows of the `top_three_indices` array
for i, top_three in enumerate(top_three_indices):
    # Get the index of the current row
    index = i
    # Get the corresponding rows from `df_e`
    matches = df_e.loc[df_e['id'].isin(top_three)]
    matches = matches.reindex(index=top_three).reset_index(drop=True)
    
    # Create a new row to add to `result_df`
    new_row= {'id': index}
    
    # Loop over the matches and add their headlines and dates to the new row
    for j, match_row in matches.iterrows():
        new_row[f'Sim{j+1}'] = match_row['headline']
        new_row[f'date{j+1}'] = match_row['last_update']
        new_row[f'cos{j+1}'] = c[i][top_three[j]]
        new_row[f'tickers{j+1}'] = match_row['tickers']
    
    # Add the new row to `sim_df`
    sim_df = sim_df.append(new_row, ignore_index=True)

# %%
merged_df = pd.merge(df_c, sim_df, on='id')
merged_df.to_parquet('/mnt/research-live/user/yzhong/Translation_similarity_2012_1_10.parquet')
df_sim=pd.read_parquet("/mnt/research-live/user/yzhong/Translation_similarity_2012_1_10.parquet")

# %%
with open('/mnt/research-live/user/yzhong/Translation_similarity_2012_1_10.txt', 'w') as f:
    for row in merged_df.itertuples():
        f.write(str(row.headline) + '\n')
        f.write(str(row.tickers) + '\n')
        f.write(str(row.translation) + '\n')
        f.write(str(row.tickers1) + '\n')
        f.write(f' Sim1: {row.cos1}  {row.Sim1}' + '\n')
        f.write(str(row.tickers2) + '\n')
        f.write(f' Sim2: {row.cos2} {row.Sim2}' + '\n')
        f.write(str(row.tickers3) + '\n')
        f.write(f' Sim3: {row.cos3} {row.Sim3}' + '\n')

# %%
def sim_dataframe (similarity_matrix,df_e,df_c):
    # Create an empty dataframe to store the three closest neighbours for each sentences
    sim_df = pd.DataFrame(columns=['id', 'Sim1', 'Sim2', 'Sim3', 'date1', 'date2', 'date3','cos1', 'cos2', 'cos3'])
    for i, dic in enumerate(similarity_matrix):
        index=i
        top_three=[dic[x]['corpus_id'] for x in range(3)]
        top_three_score=[dic[x]['score'] for x in range(3)]
        # Get the corresponding rows from `df_e`
        print(df_e.columns)
        matches = df_e.loc[df_e['id'].isin(top_three)]
        matches = matches.reindex(index=top_three).reset_index(drop=True)
        # Create a new row to add to `result_df`
        new_row= {'id': index}

        # Loop over the matches and add their headlines and dates to the new row
        for j, match_row in matches.iterrows():
            new_row[f'Sim{j+1}'] = match_row['headline']
            new_row[f'date{j+1}'] = match_row['last_update']
            new_row[f'cos{j+1}'] = top_three_score[j]
        
        # Add the new row to `sim_df`
        sim_df = sim_df.append(new_row, ignore_index=True)
        print(df_c.columns)
        merged_df = pd.merge(df_c, sim_df, on='id')

    return merged_df

# %%
merged_df = pd.merge(df_c_t, sim_df, on='id')
merged_df.to_parquet('translated_similarity_2016_03_01.parquet')
df_sim=pd.read_parquet("translated_similarity_2016_03_01.parquet")

# %%
with open('translated_similarity.txt', 'w') as f:
    for row in merged_df.itertuples():
        f.write(str(row.headline) + '\n')
        f.write(str(row.translation) + '\n')
        f.write(f' Sim1: {row.cos1}  {row.Sim1}' + '\n')
        f.write(f' Sim2: {row.cos2} {row.Sim2}' + '\n')
        f.write(f' Sim3: {row.cos3} {row.Sim3}' + '\n')

# %%
chinese_emb.shape # shape1 sentences shape2 dimensions of embeddings
# Out:
# (302, 1024)

# %% [markdown]
# Read data

# %%
def sim_dataframe (similarity_matrix,df_e,df_c):
    # Create an empty dataframe to store the three closest neighbours for each sentences
    sim_df = pd.DataFrame(columns=['id', 'Sim1', 'Sim2', 'Sim3', 'date1', 'date2', 'date3','cos1', 'cos2', 'cos3'])
    for i, dic in enumerate(similarity_matrix):
        index=i
        top_three=[dic[x]['corpus_id'] for x in range(3)]
        top_three_score=[dic[x]['score'] for x in range(3)]
        # Get the corresponding rows from `df_e`
        print(df_e.columns)
        matches = df_e.loc[df_e['id'].isin(top_three)]
        matches = matches.reindex(index=top_three).reset_index(drop=True)
        # Create a new row to add to `result_df`
        new_row= {'id': index}

        # Loop over the matches and add their headlines and dates to the new row
        for j, match_row in matches.iterrows():
            new_row[f'Sim{j+1}'] = match_row['headline']
            new_row[f'date{j+1}'] = match_row['last_update']
            new_row[f'cos{j+1}'] = top_three_score[j]
        
        # Add the new row to `sim_df`
        sim_df = sim_df.append(new_row, ignore_index=True)
        print(df_c.columns)
        merged_df = pd.merge(df_c, sim_df, on='id')

    return merged_df

# %%
def find_match(df1,df2):
    #df1 chinese df2 english
    #df1.dropna(inplace=True)
    #df1.reset_index(drop=True, inplace=True)
    #df1=df1.reset_index().rename(columns={'index': 'id'})
    #print(df1.columns)

    df2.dropna(inplace=True)
    df2.reset_index(drop=True, inplace=True)
    df2=df2.reset_index().rename(columns={'index': 'id'})

    df1.loc[:,"translation"] = df1.translation.apply(lambda x: clean_str(x))
    df2.loc[:,"headline"] = df2.headline.apply(lambda x: clean_str(x))
    ds_t = Dataset.from_dict(df1)
    ds_e = Dataset.from_dict(df2)
    cols_to_remove = ds_t.column_names
    cols_to_remove.remove("translation")
    cols_to_remove.remove("id")
    ds_t1=ds_t.remove_columns(cols_to_remove)
    cols_to_remove = ds_e.column_names
    cols_to_remove.remove("headline")
    cols_to_remove.remove("id")
    ds_e1=ds_e.remove_columns(cols_to_remove)
    ds_t1 = ds_t1.map(lambda x: compute_length(x, text='translation'), batched=True).sort('length', reverse=True)
    ds_t1 = ds_t1.map(lambda x: sentence_embeddings(x ,model, text='translation'), batched=True, batch_size=batch_size).sort('id')
    ds_e1 = ds_e1.map(lambda x: compute_length(x, text='headline'), batched=True).sort('length', reverse=True)
    ds_e1 = ds_e1.map(lambda x: sentence_embeddings(x, model,text='headline'), batched=True, batch_size=batch_size).sort('id')
    translated_input_ids=ds_t1['embeddings']
    originated_input_ids=ds_e1['embeddings']
    emb1=torch.tensor(translated_input_ids)
    emb2=torch.tensor(originated_input_ids)
    similarity_matrix=util.semantic_search(emb1, emb2, top_k=3)
    merge_df=sim_dataframe (similarity_matrix,df2,df1)
    return merge_df

# %%
df_c=pd.read_parquet('/mnt/research-live/user/yzhong/Chinese news data/2011/bloomberg_news_chinese_2011_4.parquet')
import glob
import pandas as pd
file_list = glob.glob('/mnt/research-live/user/yzhong/English_news_data/2011/04/*.parquet')
dfs = []
for file_path in file_list:
    df = pd.read_parquet(file_path)
    dfs.append(df)
df_e = pd.concat(dfs, axis=0)

# %%
df_c.loc[:,"translation"] = df_c.translation.apply(lambda x: clean_str(x))
df_e.loc[:,"headline"] = df_e.headline.apply(lambda x: clean_str(x))

# %%
df_e.dropna(inplace=True)
df_e.reset_index(drop=True, inplace=True)
df_e=df_e.reset_index().rename(columns={'index': 'id'})

# %%
ds_t = Dataset.from_dict(df_c)
ds_e = Dataset.from_dict(df_e)
ne=len(ds_e['headline'])
nt=len(ds_t['translation'])
print (f'English news: {ne}')
print (f'Chinese news: {nt}')

# %%
cols_to_remove = ds_t.column_names
cols_to_remove.remove("translation")
cols_to_remove.remove("id")
ds_t1=ds_t.remove_columns(cols_to_remove)
ds_t1
cols_to_remove = ds_e.column_names
cols_to_remove.remove("headline")
cols_to_remove.remove("id")
ds_e1=ds_e.remove_columns(cols_to_remove)
ds_e1

# %%
ds_t1 = ds_t1.map(lambda x: compute_length(x, text='translation'), batched=True).sort('length', reverse=True)
ds_t1 = ds_t1.map(lambda x: sentence_embeddings(x ,model, text='translation'), batched=True, batch_size=batch_size).sort('id')
ds_e1 = ds_e1.map(lambda x: compute_length(x, text='headline'), batched=True).sort('length', reverse=True)
ds_e1 = ds_e1.map(lambda x: sentence_embeddings(x, model,text='headline'), batched=True, batch_size=batch_size).sort('id')

# %%
translated_input_ids=ds_t1['embeddings']
originated_input_ids=ds_e1['embeddings']
emb1=torch.tensor(translated_input_ids)
emb2=torch.tensor(originated_input_ids)
similarity_matrix=util.semantic_search(emb1, emb2, top_k=3)

# %%
similarity_matrix

# %%
# Create an empty dataframe to store the three closest neighbours for each sentences
sim_df = pd.DataFrame(columns=['id', 'Sim1', 'Sim2', 'Sim3', 'date1', 'date2', 'date3','cos1', 'cos2', 'cos3'])
for i, dic in enumerate(similarity_matrix):
    index=i
    top_three=[dic[x]['corpus_id'] for x in range(3)]
    top_three_score=[dic[x]['score'] for x in range(3)]
    # Get the corresponding rows from `df_e`
    matches = df_e.loc[df_e['id'].isin(top_three)]
    matches = matches.reindex(index=top_three).reset_index(drop=True)
    # Create a new row to add to `result_df`
    new_row= {'id': index}

    # Loop over the matches and add their headlines and dates to the new row
    for j, match_row in matches.iterrows():
        new_row[f'Sim{j+1}'] = match_row['headline']
        new_row[f'date{j+1}'] = match_row['last_update']
        new_row[f'cos{j+1}'] = top_three_score[j]
    
    # Add the new row to `sim_df`
    sim_df = sim_df.append(new_row, ignore_index=True)

# %%
sim_df

# %%
import os
import pandas as pd

# Create the folder to store the monthly data
os.makedirs("/mnt/live/user/yzhong/Chinese_news_data_t", exist_ok=True)

# Read the data
df = pd.read_parquet("/mnt/research-live/user/yzhong/bloomberg_news_chinese_trickers_translation_emb.parquet")

# Extract year and month from the 'date' column
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df['day'] = pd.DatetimeIndex(df['date']).day


for year in df['year'].unique():
    year_folder_path = os.path.join("/mnt/live/user/yzhong/Chinese_news_data_t", str(year))
    os.makedirs(year_folder_path, exist_ok=True)
    for month in df.loc[df['year'] == year, 'month'].unique():
        month_folder_path = os.path.join("/mnt/live/user/yzhong/Chinese_news_data_t",str(year), str(month))
        os.makedirs(month_folder_path, exist_ok=True)
        #print(month_folder_path)
        for day in df.loc[(df['year'] == year)&(df['month'] == month), 'day'].unique():
            #print(day)
            day_df = df.loc[(df['year'] == year) & (df['month'] == month)&(df['day'] == day)]
            del day_df['year']
            del day_df['month']
            del day_df['day']
            filename = f"bloomberg_news_chinese_{str(year)}_{str(month)}_{str(day)}.parquet"
            filepath = os.path.join(month_folder_path, filename)
            day_df.to_parquet(filepath)
